# %%
# !pip list
# Out:
# Package                  Version
# ------------------------ -------------------
# absl-py                  0.11.0
# alembic                  1.4.3
# aniso8601                8.1.0
# anyio                    2.2.0
# appdirs                  1.4.4
# appnope                  0.1.2
# argon2-cffi              20.1.0
# asgiref                  3.3.1
# astroid                  2.4.2
# astunparse               1.6.3
# async-generator          1.10
# attrs                    20.3.0
# autopep8                 1.5.4
# Babel                    2.9.0
# backcall                 0.2.0
# black                    19.10b0
# bleach                   3.3.0
# blinker                  1.4
# brotlipy                 0.7.0
# cachetools               4.2.0
# certifi                  2020.12.5
# cffi                     1.14.5
# chardet                  4.0.0
# click                    7.1.2
# colorama                 0.4.4
# conda                    4.10.1
# conda-package-handling   1.7.3
# ...

# %%
import numpy as np
from matplotlib import pyplot as plt


fg, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-bd40c29de268> in <module>
#       1 import numpy as np
# ----> 2 from matplotlib import pyplot as plt
#       3
#       4
#       5 fg, ax = plt.subplots()
#
# ImportError: cannot import name 'pyplot' from 'matplotlib' (unknown location)
