# %%
# %config IPCompleter.greedy=True

# %%
import pandas as pd
import numpy as np


s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
dates = pd.date_range('20191201', periods=6)
# create df
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('abcd'))

# create df by passing a dictionary
d = {
    'A': 1,
    'B': pd.Timestamp('20191201'),
    'C': pd.Series(1, index=list(range(4)), dtype='float32'),
    'D': np.array([3]*4, dtype='int32'),
    'E': pd.Categorical(['test','train', 'test', 'train']),
    'F': 'foo'
}
df1 = pd.DataFrame(d)
# df1.dtypes
df1.T.T
# Out:
#    A          B  C  D      E    F
# 0  1 2019-12-01  1  3   test  foo
# 1  1 2019-12-01  1  3  train  foo
# 2  1 2019-12-01  1  3   test  foo
# 3  1 2019-12-01  1  3  train  foo

# %%
import pandas as pd

df = pd.read_csv('hcm_200615.csv', encoding="utf-8")
pd.set_option('display.max_columns', 19)
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156019 entries, 0 to 156018
# Data columns (total 19 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   NhanVienGiao     156019 non-null  object
#  1   NhanVienXuLy     156019 non-null  object
#  2   TrangThai        156019 non-null  object
#  3   BuuCuc           156019 non-null  object
#  4   GoiCuoc          156019 non-null  object
#  5   Loai             156019 non-null  object
#  6   KV               156019 non-null  object
#  7   DenQuan          156019 non-null  object
#  8   TGGiaoThanhCong  156019 non-null  object
#  9   MaDH             156019 non-null  object
#  10  TrongLuong       156019 non-null  int64
#  11  TenShop          156019 non-null  object
#  12  MaKho            156019 non-null  int64
#  13  KichThuoc        156019 non-null  object
#  14  NULL1            0 non-null       float64
#  15  MaCD             156019 non-null  object
#  16  NULL2            156019 non-null  float64
#  17  LoaiHang         156019 non-null  object
#  18  NULL3            0 non-null       float64
# dtypes: float64(3), int64(2), object(14)
# memory usage: 22.6+ MB
#                        NhanVienGiao                     NhanVienXuLy  \
# 0         1708553 - Huỳnh Khánh Kim        1708553 - Huỳnh Khánh Kim
# 1         1708553 - Huỳnh Khánh Kim        1708553 - Huỳnh Khánh Kim
# 2          208235 - LƯƠNG DUY TRUNG  1815407 - NGUYỄN TRẦN ÁNH TUYẾT
# 3          208235 - LƯƠNG DUY TRUNG  1815407 - NGUYỄN TRẦN ÁNH TUYẾT
# 4          208235 - LƯƠNG DUY TRUNG  1815407 - NGUYỄN TRẦN ÁNH TUYẾT
# ...                             ...                              ...
# 156014       1871722 - Lê Tiến Mạnh           1871722 - Lê Tiến Mạnh
# 156015       1871722 - Lê Tiến Mạnh           1871722 - Lê Tiến Mạnh
# 156016       1871722 - Lê Tiến Mạnh           1871722 - Lê Tiến Mạnh
# 156017  2039005 - Dương Lê Gia Ngọc          255443 - Phùng Tâm Minh
# 156018       2038304 - Đỗ Đức Chung            1874901 - Lê Xuân Lảm
#
#                    TrangThai                                     BuuCuc  \
# 0            Giao thanh cong  Bưu Cục 292 Đinh Bộ Lĩnh-Q.Bình Thạnh-HCM
# 1            Giao thanh cong  Bưu Cục 292 Đinh Bộ Lĩnh-Q.Bình Thạnh-HCM
# 2       Lay khong thanh cong                 Bưu Cục 05 Đường 8-Q.9-HCM
# 3             Lay thanh cong                 Bưu Cục 05 Đường 8-Q.9-HCM
# 4             Lay thanh cong                 Bưu Cục 05 Đường 8-Q.9-HCM
# ...                      ...                                        ...
# 156014        Tra thanh cong        Bưu Cục 640 Lê Đức Thọ-Q.Gò Vấp-HCM
# 156015        Tra thanh cong        Bưu Cục 640 Lê Đức Thọ-Q.Gò Vấp-HCM
# 156016        Tra thanh cong        Bưu Cục 640 Lê Đức Thọ-Q.Gò Vấp-HCM
# 156017          Giao luu kho      Bưu Cục 16A Lê Hồng Phong-Q.10-HCM 02
# 156018       Giao thanh cong       Bưu Cục 02 Nguyễn Hới-Q.Bình Tân-HCM
#
#        GoiCuoc  Loai           KV                       DenQuan  \
# 0       2 Ngày  NoiT  Hồ Chí Minh   Quận Bình Thạnh-Hồ Chí Minh
# 1       1 Ngày  NoiT  Hồ Chí Minh   Quận Bình Thạnh-Hồ Chí Minh
# 2       2 Ngày  NT 1  Hồ Chí Minh            Quận 9-Hồ Chí Minh
# 3       2 Ngày  NT 1  Hồ Chí Minh            Quận 9-Hồ Chí Minh
# 4       1 Ngày  NT 1  Hồ Chí Minh            Quận 9-Hồ Chí Minh
# ...        ...   ...          ...                           ...
# 156014  1 Ngày  NoiT  Hồ Chí Minh       Quận Gò Vấp-Hồ Chí Minh
# 156015  1 Ngày  NoiT  Hồ Chí Minh       Quận Gò Vấp-Hồ Chí Minh
# 156016  3 Ngày  NoiT  Hồ Chí Minh       Quận Gò Vấp-Hồ Chí Minh
# 156017  1 Ngày  NoiT  Hồ Chí Minh           Quận 11-Hồ Chí Minh
# 156018  3 Ngày  NT 2  Hồ Chí Minh  Huyện Bình Chánh-Hồ Chí Minh
#
#        TGGiaoThanhCong         MaDH  TrongLuong             TenShop  MaKho  \
# 0        6/15/20 16:02     FFUULLQA         150      Shopee - 18692   2428
# 1        6/15/20 16:02    FEFQ13Q6L         500    Vận hành - 32821   2428
# 2        6/15/20 05:39     FFSLRU5Q         800   KiotViet - 518873   1326
# 3        6/13/20 15:51     FF3945HH         300      Shopee - 18692   1326
# 4        6/13/20 10:25     FFH6FDAD         300      Shopee - 18692   1326
# ...                ...          ...         ...                 ...    ...
# 156014   6/15/20 21:55     FFUDXRKN         600      Shopee - 18692   2276
# 156015   6/15/20 21:55     FFXKSS1A         300      Shopee - 18692   2276
# 156016   6/15/20 21:55  SG101929098         200     sendo.vn - 1539   2276
# 156017   6/15/20 21:58     FFFYLAXY        1200      Shopee - 18692   2420
# 156018   6/15/20 21:59     FFXYQ6NQ         200  shop vân - 1266153   1333
#
#        KichThuoc  NULL1           MaCD      NULL2 LoaiHang  NULL3
# 0       10x10x10    NaN  2062428ZH9702  3263567.0     Giao    NaN
# 1       10x10x10    NaN  2062428ZH9702  3363768.0     Giao    NaN
# 2        10x10x6    NaN  2061326TETG25  3295806.0      Lấy    NaN
# 3       10x10x10    NaN  2061326TETG25   263728.0      Lấy    NaN
# 4       10x10x10    NaN  2061326TETG25  2575733.0      Lấy    NaN
# ...          ...    ...            ...        ...      ...    ...
# 156014  10x10x10    NaN  2062276UWJT24  2341415.0      Trả    NaN
# 156015  10x10x10    NaN  2062276UWJT24  1693225.0      Trả    NaN
# 156016  10x10x10    NaN  2062276UWJT24  2728763.0      Trả    NaN
# 156017  10x10x10    NaN  2062420HEX957  2144350.0     Giao    NaN
# 156018  10x10x10    NaN  2061333K8Z916  3372486.0     Giao    NaN
#
# [156019 rows x 19 columns]
