# %%
# !pip install openpyxl
# Out:
# ...
#      |████████████████████████████████| 242 kB 574 kB/s
# ...

# %%
# !pip install vietnam_provinces
# Out:
# ...
#      |████████████████████████████████| 718 kB 614 kB/s
# ...
#      |████████████████████████████████| 85 kB 2.2 MB/s
#   Preparing metadata (setup.py) ... done
# ...
#      |████████████████████████████████| 235 kB 6.7 MB/s
# ...
#   Created wheel for logbook: filename=Logbook-1.5.3-cp39-cp39-linux_x86_64.whl size=66392 sha256=b9d5c06315cec2119f4cb5da5085b0d3d6055b136a09ceba885bcbb990b181ef
#   Stored in directory: /home/phuoc/.cache/pip/wheels/b2/87/64/bc96601e8797f86d972db77d78c18e2d102991bcc027657c4a
# Successfully built logbook
# ...

# %%
import pandas as pd
import numpy as np
import os
import requests
import re
# import vietnam_provinces
# from vietnam_provinces.enums import ProvinceEnum

# %%
address = 'cư lại phú hải phú quang huế'
API_KEY = 'AIzaSyBLIdBy6-aEvWMbBb9kCy8JXiblqLMr9yI'

r = requests.get(f'https://maps.googleapis.com/maps/api/geocode/json?address={address}&key={API_KEY}')

r.json()['results'][0]['address_components'][3]['long_name']
# Out:
# 'Thừa Thiên Huế'

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  '.ipynb_checkpoints',
#  'Untitled.ipynb',
#  'data',
#  'handle_duplicates.ipynb',
#  'handle_njv_data.ipynb',
#  'handle_snp_data.ipynb',
#  'handling_snp2.ipynb',
#  'new-data']

# %%
os.chdir('data')

# %%
# provinces = []
# for e in total['To Address'].tolist():
#     r = requests.get(f'https://maps.googleapis.com/maps/api/geocode/json?address={e}&key={API_KEY}')
    
#     provinces.append(r.json()['results'][0]['address_components'][3]['long_name'])
                     
# print(provinces)
# len(total['To Address'].tolist())

# %%
import re
import vietnam_provinces
from vietnam_provinces.enums import ProvinceEnum


def location(address: str) -> str:
    # provinces = '''
    #     Hà Nội  Hà Giang  Cao Bằng  Bắc Kạn  Tuyên Quang 
    #     Lào Cai  Điện Biên  Lai Châu  Sơn La  Yên Bái  
    #     Hoà Bình  Thái Nguyên  Lạng Sơn  Quảng Ninh  Bắc Giang  
    #     Phú Thọ  Vĩnh Phúc  Bắc Ninh  Hải Dương  Hải Phòng  
    #     Hưng Yên  Thái Bình  Hà Nam  Nam Định  Ninh Bình  T
    #     hanh Hóa  Nghệ An  Hà Tĩnh  Quảng Bình  Quảng Trị  
    #     Thừa Thiên Huế  Đà Nẵng  Quảng Nam  Quảng Ngãi  Bình Định  
    #     Phú Yên  Khánh Hòa  Ninh Thuận  Bình Thuận  Kon Tum  Gia Lai  
    #     Đắk Lắk  Đắk Nông  Lâm Đồng  Bình Phước  Tây Ninh  Bình Dương  
    #     Đồng Nai  Bà Rịa Vũng Tàu  Hồ Chí Minh  Long An  Tiền Giang  
    #     Bến Tre  Trà Vinh  Vĩnh Long  Đồng Tháp  An Giang  Kiên Giang  
    #     Cần Thơ  Hậu Giang  Sóc Trăng  Bạc Liêu  Cà Mau'''
    
    
    raw = '''
    h.?\sch.?\sm.?nh|h.?\sn.?i|h.?\sgiang|c.?o\sb.?ng|
    b.?c\sk.?n|tuy.?n\squang|l.?o\scai|.?i.?n\sbi.?n|lai\sch.?u|s.?n\sla|
    y.?n\sb.?i|h.?.?\sb.?nh|th.?i\snguy.?n|l.?ng\ss.?n|qu.?ng\sninh|b.?c\sgiang|
    ph.?\sth.?|v.?nh\sph.?c|b.?c\sninh|h.?i\sd.?.?ng|h.?i\sph.?ng|h.?ng\sy.?n|
    th.?i\sb.?nh|h.?\snam|nam\s.?.?nh|ninh\sb.?nh|thanh\sh.?.?|ngh.?\san|h.?\st.?nh|
    qu.?ng\sb.?nh|qu.?ng\str.?|th.?a\sthi.?n\shu.?|.?.?\sn.?ng|qu.?ng\snam|qu.?ng\sng.?i|
    b.?nh\s.?.?nh|ph.?\sy.?n|kh.?nh\sh.?a|ninh\sthu.?n|b.?nh\sthu.?n|kon\stum|
    gia\slai|.?.?k\sl.?k|.?.?k\sn.?ng|l.?m\s.?.?ng|b.?nh\sph.?.?c|t.?y\sninh|
    b.?nh\sd.?.?ng|.?.?ng\snai|b.?\sr.?a\s-\sv.?ng\st.?u|long\san|ti.?n\sgiang|
    b.?n\stre|tr.?\svinh|v.?nh\slong|.?.?ng\sth.?p|an\sgiang|ki.?n\sgiang|c.?n\sth.?|
    h.?u\sgiang|s.?c\str.?ng|b.?c\sli.?u|c.?\smau|hn|hcm
    '''
    r = raw.split('?')
    raw = ''.join(r).strip()
    # print(''.join(r))
    
    pattern = re.compile(raw, flags=re.IGNORECASE)
    
    try:
        result =  pattern.search(address).group()
        return result
    except:
        return "sai dia chi"


    
# location('1')


    
location('41A Lý Thái Tổ - Quận Hoàn Kiếm, Hà Nội')


# data['Address'] = data['To Address'].apply(lambda x: location(x))

# data.head()
# Out:
# 'Hà Nội'

# %%
os.listdir()
# Out:
# ['.DS_Store', 'data-total.xlsx', 'sent-phones.xlsx']

# %%
os.chdir('..')

# %%
os.chdir('..')

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  '.ipynb_checkpoints',
#  'Untitled.ipynb',
#  'data',
#  'handle_duplicates.ipynb',
#  'handle_njv_data.ipynb',
#  'handle_snp_data.ipynb',
#  'handling_snp2.ipynb',
#  'new-data']

# %%
os.chdir('new-data')

# %%
import glob
import numpy as np

# read and merge multiple excel file

# cols = ['Mã DN', 'Tên DN', 'SĐT Gửi hàng', 'Mã vận đơn', 'Mã đơn của Shop', 'Đối tác VC', 'Tỉnh/ Thành phố gửi', 'Quận/ Huyện gửi', 'Người nhận', 'Địa chỉ', 'Tỉnh/ Thành phố giao', 'Quận/ Huyện giao', 'Phường/ Xã giao', 'Số điện thoại']
ext = 'xlsx'
files = [i for i in glob.glob(f'trackings*.{ext}')]

combine = pd.concat([pd.read_excel(f) for f in files])
combine.head()
# Out:
#      Mã DN                                             Tên DN  SĐT Gửi hàng  \
# 0  19291.0                                           SAPO NEW    0969619319
# 1  22798.0  Góc hàng nhà  Nấm (Natasha Nam) - Săn sale các...    0949698187
# 2   3969.0                                       Phương Thanh  +84983238416
# 3   3969.0                                       Phương Thanh  +84983238416
# 4   3295.0                                         Shop Bố Sò  +84936088909
#
#      Mã vận đơn                       Mã đơn của Shop Đối tác VC  \
# 0  SNP254005802  9bf3dd1b-b27f-40d6-a1ce-7c96180e6395        NaN
# 1  SNP644005803                                   NaN        NaN
# 2  SNP674005804                                   NaN        NaN
# 3  SNP264005805                                   NaN        NaN
# 4  SNP264005828                                   NaN        NaN
#
#   Tỉnh/ Thành phố gửi Quận/ Huyện gửi                   Người nhận  \
# ...

# %%
combine.drop(['Mã vận đơn', 'Mã đơn của Shop'], inplace=True, axis=1)

combine.head()
# Out:
#      Mã DN                                             Tên DN  SĐT Gửi hàng  \
# 0  19291.0                                           SAPO NEW    0969619319
# 1  22798.0  Góc hàng nhà  Nấm (Natasha Nam) - Săn sale các...    0949698187
# 2   3969.0                                       Phương Thanh  +84983238416
# 3   3969.0                                       Phương Thanh  +84983238416
# 4   3295.0                                         Shop Bố Sò  +84936088909
#
#   Đối tác VC Tỉnh/ Thành phố gửi Quận/ Huyện gửi                   Người nhận  \
# 0        NaN              Hà Nội    Quận Hà Đông                     Loan Ngô
# 1        NaN              Hà Nội   Quận Cầu Giấy  Nguyễn Thị Phương Dung
# 2        NaN              Hà Nội  Quận Hoàng Mai           Cô Dung (cậu Hùng)
# 3        NaN              Hà Nội  Quận Hoàng Mai            Nguyen Thanh Loan
# 4        NaN              Hà Nội    Quận Đống Đa                      Bao Anh
#
# ...

# %%
combine.drop(['Unnamed: 0', 'Unnamed: 1'], inplace=True, axis=1)
combine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 384530 entries, 0 to 4723
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Mã DN                 384526 non-null  float64
#  1   Tên DN                384526 non-null  object
#  2   SĐT Gửi hàng          384526 non-null  object
#  3   Đối tác VC            114850 non-null  object
#  4   Tỉnh/ Thành phố gửi   384526 non-null  object
#  5   Quận/ Huyện gửi       384526 non-null  object
#  6   Người nhận            384526 non-null  object
#  7   Địa chỉ               384526 non-null  object
#  8   Tỉnh/ Thành phố giao  384526 non-null  object
#  9   Quận/ Huyện giao      384526 non-null  object
#  10  Phường/ Xã giao       342188 non-null  object
#  11  Số điện thoại         384526 non-null  float64
# dtypes: float64(2), object(10)
# memory usage: 38.1+ MB

# %%
combine['Mã DN'] = combine['Mã DN'].astype('Int64', errors='ignore')
combine['Số điện thoại'] = combine['Số điện thoại'].astype('Int64', errors='ignore').astype(str).apply(lambda x: '0' + x)
combine.head()
# Out:
#    Mã DN                                             Tên DN  SĐT Gửi hàng  \
# 0  19291                                           SAPO NEW    0969619319
# 1  22798  Góc hàng nhà  Nấm (Natasha Nam) - Săn sale các...    0949698187
# 2   3969                                       Phương Thanh  +84983238416
# 3   3969                                       Phương Thanh  +84983238416
# 4   3295                                         Shop Bố Sò  +84936088909
#
#   Đối tác VC Tỉnh/ Thành phố gửi Quận/ Huyện gửi                   Người nhận  \
# 0        NaN              Hà Nội    Quận Hà Đông                     Loan Ngô
# 1        NaN              Hà Nội   Quận Cầu Giấy  Nguyễn Thị Phương Dung
# 2        NaN              Hà Nội  Quận Hoàng Mai           Cô Dung (cậu Hùng)
# 3        NaN              Hà Nội  Quận Hoàng Mai            Nguyen Thanh Loan
# 4        NaN              Hà Nội    Quận Đống Đa                      Bao Anh
#
# ...

# %%
combine.to_excel('data-snp-1.6-to-1.8.xlsx', index=False)

# %%
# combine[combine['Tên DN'] == 'fahasa']

# %%
flt = (combine['Tên DN'] == 'fahasa') | (combine['Tên DN'] == 'Newshop')

normal = combine[~flt]
normal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 313939 entries, 0 to 4723
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Mã DN                 313935 non-null  Int64
#  1   Tên DN                313935 non-null  object
#  2   SĐT Gửi hàng          313935 non-null  object
#  3   Đối tác VC            108339 non-null  object
#  4   Tỉnh/ Thành phố gửi   313935 non-null  object
#  5   Quận/ Huyện gửi       313935 non-null  object
#  6   Người nhận            313935 non-null  object
#  7   Địa chỉ               313935 non-null  object
#  8   Tỉnh/ Thành phố giao  313935 non-null  object
#  9   Quận/ Huyện giao      313935 non-null  object
#  10  Phường/ Xã giao       272469 non-null  object
#  11  Số điện thoại         313939 non-null  object
# dtypes: Int64(1), object(11)
# memory usage: 31.4+ MB

# %%
combine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 384530 entries, 0 to 4723
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Mã DN                 384526 non-null  Int64
#  1   Tên DN                384526 non-null  object
#  2   SĐT Gửi hàng          384526 non-null  object
#  3   Đối tác VC            114850 non-null  object
#  4   Tỉnh/ Thành phố gửi   384526 non-null  object
#  5   Quận/ Huyện gửi       384526 non-null  object
#  6   Người nhận            384526 non-null  object
#  7   Địa chỉ               384526 non-null  object
#  8   Tỉnh/ Thành phố giao  384526 non-null  object
#  9   Quận/ Huyện giao      384526 non-null  object
#  10  Phường/ Xã giao       342188 non-null  object
#  11  Số điện thoại         384530 non-null  object
# dtypes: Int64(1), object(11)
# memory usage: 38.5+ MB

# %%
combine[flt].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70591 entries, 32 to 4394
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Mã DN                 70591 non-null  Int64
#  1   Tên DN                70591 non-null  object
#  2   SĐT Gửi hàng          70591 non-null  object
#  3   Đối tác VC            6511 non-null   object
#  4   Tỉnh/ Thành phố gửi   70591 non-null  object
#  5   Quận/ Huyện gửi       70591 non-null  object
#  6   Người nhận            70591 non-null  object
#  7   Địa chỉ               70591 non-null  object
#  8   Tỉnh/ Thành phố giao  70591 non-null  object
#  9   Quận/ Huyện giao      70591 non-null  object
#  10  Phường/ Xã giao       69719 non-null  object
#  11  Số điện thoại         70591 non-null  object
# dtypes: Int64(1), object(11)
# memory usage: 7.1+ MB

# %%
no_student = normal[['Người nhận', 'Địa chỉ', 'Tỉnh/ Thành phố giao', 'Quận/ Huyện giao', 'Phường/ Xã giao', 'Số điện thoại']]
no_student.drop_duplicates(subset=['Số điện thoại'], inplace=True, keep='first')

no_student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 244752 entries, 0 to 4723
# Data columns (total 6 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Người nhận            244751 non-null  object
#  1   Địa chỉ               244751 non-null  object
#  2   Tỉnh/ Thành phố giao  244751 non-null  object
#  3   Quận/ Huyện giao      244751 non-null  object
#  4   Phường/ Xã giao       213183 non-null  object
#  5   Số điện thoại         244752 non-null  object
# dtypes: object(6)
# memory usage: 13.1+ MB
# /opt/conda/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
os.chdir('..')
os.listdir()
# Out:
# ['.DS_Store',
#  '.ipynb_checkpoints',
#  'Untitled.ipynb',
#  'data',
#  'handle_duplicates.ipynb',
#  'handle_njv_data.ipynb',
#  'handle_snp_data.ipynb',
#  'handling_snp2.ipynb',
#  'new-data']

# %%
os.chdir('data/sent-phone')

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  '10 k fone 4.xlsx',
#  '10 k mobi 7.xlsx',
#  '10 k vinafone 2.xlsx',
#  '10 mobi 6.xlsx',
#  '10 phone  11.xlsx',
#  '10k fone 3.xlsx',
#  '10k fone 5.xlsx',
#  '10k mobi 8.xlsx',
#  '10k phone 10.xlsx',
#  '10k phone 12.xlsx',
#  '10k6 phone 11.xlsx',
#  '14k3 phoen 13.xlsx',
#  '15K PHONE 14.xlsx',
#  '15K PHONE 16.xlsx',
#  'Book1.xlsx',
#  'phuoc']

# %%
os.chdir('phuoc')

# %%
ext = 'xlsx'
files = [i for i in glob.glob(f'data-nguoi-nhan*.{ext}')]

sent1 = pd.concat([pd.read_excel(f) for f in files])
sent1.head()
# Out:
#                     Người nhận  \
# 0                     Loan Ngô
# 1  Nguyễn Thị Phương Dung
# 2            Nguyen Thanh Loan
# 3                      Bao Anh
# 4                    chị Linh,
#
#                                              Địa chỉ Tỉnh/ Thành phố giao  \
# 0  Ngô Thị Hồng - văn phòng UBND quận Ngô Quyền 1...            Hải Phòng
# 1  nguyễn thị phương dung số 40 đường s...              Long An
# 2            41A Lý Thái Tổ - Quận Hoàn Kiếm, Hà Nội               Hà Nội
# 3  số 1 ngách 84/5 Đàm Quang Trung tổ 22 - Phường...               Hà Nội
# 4  548/52 Tân kỳ Tân quý Phường binh hung hoa - P...          Hồ Chí Minh
#
#    Quận/ Huyện giao       Phường/ Xã giao  Số điện thoại       ISP
# 0    Quận Ngô Quyền         Phường Máy Tơ      987928887   Viettel
# 1  Thành phố Tân An              Phường 6      908413839  Mobifone
# 2    Quận Hoàn Kiếm                   NaN      904918600  Mobifone
# ...

# %%
sent1['Số điện thoại'] = sent1['Số điện thoại'].astype(str).apply(lambda x: '0' + x)

# %%
sent1.head()
# Out:
#                     Người nhận  \
# 0                     Loan Ngô
# 1  Nguyễn Thị Phương Dung
# 2            Nguyen Thanh Loan
# 3                      Bao Anh
# 4                    chị Linh,
#
#                                              Địa chỉ Tỉnh/ Thành phố giao  \
# 0  Ngô Thị Hồng - văn phòng UBND quận Ngô Quyền 1...            Hải Phòng
# 1  nguyễn thị phương dung số 40 đường s...              Long An
# 2            41A Lý Thái Tổ - Quận Hoàn Kiếm, Hà Nội               Hà Nội
# 3  số 1 ngách 84/5 Đàm Quang Trung tổ 22 - Phường...               Hà Nội
# 4  548/52 Tân kỳ Tân quý Phường binh hung hoa - P...          Hồ Chí Minh
#
#    Quận/ Huyện giao       Phường/ Xã giao Số điện thoại       ISP
# 0    Quận Ngô Quyền         Phường Máy Tơ    0987928887   Viettel
# 1  Thành phố Tân An              Phường 6    0908413839  Mobifone
# 2    Quận Hoàn Kiếm                   NaN    0904918600  Mobifone
# ...

# %%
os.chdir('..')

# %%
ext = 'xlsx'
cols = ['name', 'phone', 'address', 'none1', 'none2', 'none3', 'none4']
files = [i for i in glob.glob(f'*.{ext}')]

sent2 = pd.concat([pd.read_excel(f, names=cols) for f in files])
sent2.head()
# Out:
#               name        phone  \
# 0        Kiều Tiên  84834108733
# 1           Thị Út  84906413147
# 2       Đức nguyễn  84903354837
# 3  Nguyễn Hoàng An  84385830034
# 4            Cường  84961579644
#
#                                              address        none1      none2  \
# 0  Trước trường mẫu giáo lâm tân  , Xã Lâm Tân , ...  84834108733  Vinaphone
# 1  11 Lý Chiêu Hoàng Phường 10 Quận 6  , Phường 1...  84906413147   Mobifone
# 2  58 thiên hộ dương,p1,gò vấp, Hồ Chí Minh, Quận...  84903354837   Mobifone
# 3  4/4G đường XTT 6-2, ấp 3  , Xã Xuân Thới Thượn...  84385830034    Viettel
# 4  Số 22, tổ 1, ấp 1, xã minh hưng, huyện chơn th...  84961579644    Viettel
#
#    none3    none4
# 0   8483  new20/6
# 1   8490  new20/6
# 2   8490  new20/6
# 3   8438  new20/6
# 4   8496  new20/6

# %%
sent2.drop(['none1', 'none2', 'none3', 'none4'], inplace=True, axis=1)
sent2.head()
# Out:
#               name        phone  \
# 0        Kiều Tiên  84834108733
# 1           Thị Út  84906413147
# 2       Đức nguyễn  84903354837
# 3  Nguyễn Hoàng An  84385830034
# 4            Cường  84961579644
#
#                                              address
# 0  Trước trường mẫu giáo lâm tân  , Xã Lâm Tân , ...
# 1  11 Lý Chiêu Hoàng Phường 10 Quận 6  , Phường 1...
# 2  58 thiên hộ dương,p1,gò vấp, Hồ Chí Minh, Quận...
# 3  4/4G đường XTT 6-2, ấp 3  , Xã Xuân Thới Thượn...
# 4  Số 22, tổ 1, ấp 1, xã minh hưng, huyện chơn th...

# %%
def validate_phone(s: str) -> str:
    if '84' in s:
        return s.replace('84', '0')
    return s

sent2['phone'] = sent2['phone'].astype(str).apply(lambda x: validate_phone(x))
sent2.head()
# Out:
#               name       phone  \
# 0        Kiều Tiên  0834108733
# 1           Thị Út  0906413147
# 2       Đức nguyễn  0903354837
# 3  Nguyễn Hoàng An  0385830034
# 4            Cường  0961579644
#
#                                              address
# 0  Trước trường mẫu giáo lâm tân  , Xã Lâm Tân , ...
# 1  11 Lý Chiêu Hoàng Phường 10 Quận 6  , Phường 1...
# 2  58 thiên hộ dương,p1,gò vấp, Hồ Chí Minh, Quận...
# 3  4/4G đường XTT 6-2, ấp 3  , Xã Xuân Thới Thượn...
# 4  Số 22, tổ 1, ấp 1, xã minh hưng, huyện chơn th...

# %%
# def remove_sent(df, sr):
#     df.drop(df[df['Số điện thoại'].isin(sr)].index, inplace=True)
    

sent_phones = pd.concat([sent1['Số điện thoại'], sent2['phone']])
# remove_sent(no_student, sent_phones)
sent_phones.drop_duplicates(inplace=True)
sent_phones
# Out:
# 0       0987928887
# 1       0908413839
# 2       0904918600
# 3       0343317086
# 4       0903648047
#            ...
# 9994    0388959983
# 9995    0868356311
# 9996    0854507810
# 9997    0788966052
# 9998    0327754591
# Length: 195026, dtype: object

# %%
no_student['sent'] = no_student['Số điện thoại'].isin(sent_phones)
no_student.drop_duplicates(subset=['Số điện thoại'], inplace=True)
# Out:
# /tmp/ipykernel_55/2729105948.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_student['sent'] = no_student['Số điện thoại'].isin(sent_phones)
# /opt/conda/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
no_student.groupby(['sent']).count()
# Out:
#        Người nhận  Địa chỉ  Tỉnh/ Thành phố giao  Quận/ Huyện giao  \
# sent
# False      217458   217458                217458            217458
# True        27293    27293                 27293             27293
#
#        Phường/ Xã giao  Số điện thoại
# sent
# False           189830         217459
# True             23353          27293

# %%
no_student_no_sent = no_student[no_student['sent'] == False]
no_student_no_sent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 217459 entries, 2 to 4723
# Data columns (total 7 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Người nhận            217458 non-null  object
#  1   Địa chỉ               217458 non-null  object
#  2   Tỉnh/ Thành phố giao  217458 non-null  object
#  3   Quận/ Huyện giao      217458 non-null  object
#  4   Phường/ Xã giao       189830 non-null  object
#  5   Số điện thoại         217459 non-null  object
#  6   sent                  217459 non-null  bool
# dtypes: bool(1), object(6)
# memory usage: 11.8+ MB

# %%
no_student_no_sent.head()
# Out:
#              Người nhận                                            Địa chỉ  \
# 2    Cô Dung (cậu Hùng)  109/39 ấp mới 2 xã trung chánh huyện hóc môn t...
# 5   Hoang Gia Hoang Gia  Về nhà thuốc hoàng Dako - Xã Đăk Ơ, Huyện Bù G...
# 6             Nguyệt An  Phường - Phường Cẩm Bình, Thành phố Cẩm Phả, Q...
# 8          Nang Mai Ngo  43 Trần Thị Nghỉ Phường 7 Quận Gò Vấp  - Phườn...
# 12         Thanh Phương  Số nhà 61 ngõ trại cá Phường - Phường Trương Đ...
#
#    Tỉnh/ Thành phố giao   Quận/ Huyện giao     Phường/ Xã giao Số điện thoại  \
# 2           Hồ Chí Minh      Huyện Hóc Môn      Xã Trung Chánh    0937166909
# 5            Bình Phước   Huyện Bù Gia Mập            Xã Đăk Ơ    0962923924
# 6            Quảng Ninh  Thành phố Cẩm Phả     Phường Cẩm Bình    0982129176
# 8           Hồ Chí Minh        Quận Gò Vấp            Phường 7    0988605417
# 12               Hà Nội  Quận Hai Bà Trưng  Phường Trương Định    0969828471
#
#      sent
# 2   False
# 5   False
# 6   False
# ...

# %%
isp_maps = {
    70: 'Mobifone',
    79: 'Mobifone',
    77: 'Mobifone',
    76: 'Mobifone',
    78: 'Mobifone',
    32: 'Viettel',
    33: 'Viettel',
    34: 'Viettel',
    35: 'Viettel',
    36: 'Viettel',
    37: 'Viettel',
    38: 'Viettel',
    39: 'Viettel',
    83: 'Vinaphone',
    84: 'Vinaphone',
    85: 'Vinaphone',
    81: 'Vinaphone',
    82: 'Vinaphone',
    97: 'Viettel',
    90: 'Mobifone',
    93: 'Mobifone',
    96: 'Viettel',
    98: 'Viettel',
    91: 'Vinaphone',
    92: 'Vietnammobile',
    94: 'Vinaphone',
    89: 'Mobifone',
    88: 'Vinaphone',
    86: 'Viettel',
    55: 'Vietnammobile',
    56: 'Vietnammobile',
    58: 'Vietnammobile',
    87: 'I-telecom',
    52: 'Vietnammobile'
}

def get_isp_name(maps, key):
     try:
        return maps.get(int(key[1:3]), np.nan)
     except ValueError:
        return np.nan
    
no_student_no_sent['ISP'] = no_student_no_sent['Số điện thoại'].astype(str).apply(lambda x: get_isp_name(isp_maps, x))

no_student_no_sent.head()
# Out:
# /tmp/ipykernel_55/390597480.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_student_no_sent['ISP'] = no_student_no_sent['Số điện thoại'].astype(str).apply(lambda x: get_isp_name(isp_maps, x))
#              Người nhận                                            Địa chỉ  \
# 2    Cô Dung (cậu Hùng)  109/39 ấp mới 2 xã trung chánh huyện hóc môn t...
# 5   Hoang Gia Hoang Gia  Về nhà thuốc hoàng Dako - Xã Đăk Ơ, Huyện Bù G...
# 6             Nguyệt An  Phường - Phường Cẩm Bình, Thành phố Cẩm Phả, Q...
# 8          Nang Mai Ngo  43 Trần Thị Nghỉ Phường 7 Quận Gò Vấp  - Phườn...
# 12         Thanh Phương  Số nhà 61 ngõ trại cá Phường - Phường Trương Đ...
#
# ...

# %%
no_student_no_sent.drop(['sent'], axis=1, inplace=True)
no_student_no_sent.head()
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#              Người nhận                                            Địa chỉ  \
# 2    Cô Dung (cậu Hùng)  109/39 ấp mới 2 xã trung chánh huyện hóc môn t...
# 5   Hoang Gia Hoang Gia  Về nhà thuốc hoàng Dako - Xã Đăk Ơ, Huyện Bù G...
# 6             Nguyệt An  Phường - Phường Cẩm Bình, Thành phố Cẩm Phả, Q...
# 8          Nang Mai Ngo  43 Trần Thị Nghỉ Phường 7 Quận Gò Vấp  - Phườn...
# 12         Thanh Phương  Số nhà 61 ngõ trại cá Phường - Phường Trương Đ...
#
#    Tỉnh/ Thành phố giao   Quận/ Huyện giao     Phường/ Xã giao Số điện thoại  \
# 2           Hồ Chí Minh      Huyện Hóc Môn      Xã Trung Chánh    0937166909
# ...

# %%
os.getcwd()
# Out:
# '/home/phuoc/work/data/sent-phone'

# %%
os.chdir('..')
os.listdir()
# Out:
# ['.DS_Store', 'august', 'new-shop.xlsx', 'outcome', 'sent-phone', 'shop.xlsx']

# %%
os.chdir('august')

# %%
def split_df(df, chunksize=10000):
    chunks = []
    num_chunks = len(df) // chunksize + 1
    for i in range(num_chunks):
        chunks.append(df[i*chunksize:(i+1)*chunksize])
    return chunks

# chunksize = 10000
# chunks = len(data) // chunksize
chunks = split_df(no_student_no_sent)

i = 0
for chunk in chunks:
    chunk.to_excel('data_{:02d}.xlsx'.format(i), index=False)
    i += 1

# %%
no_student_no_sent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 217459 entries, 2 to 4723
# Data columns (total 7 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Người nhận            217458 non-null  object
#  1   Địa chỉ               217458 non-null  object
#  2   Tỉnh/ Thành phố giao  217458 non-null  object
#  3   Quận/ Huyện giao      217458 non-null  object
#  4   Phường/ Xã giao       189830 non-null  object
#  5   Số điện thoại         217459 non-null  object
#  6   ISP                   217296 non-null  object
# dtypes: object(7)
# memory usage: 13.3+ MB

# %%
sents = pd.concat([no_student_no_sent['Số điện thoại'], sent1['Số điện thoại'], sent2['phone']])
sents.drop_duplicates(inplace=True)
sents
# Out:
# 2       0937166909
# 5       0962923924
# 6       0982129176
# 8       0988605417
# 12      0969828471
#            ...
# 9994    0388959983
# 9995    0868356311
# 9996    0854507810
# 9997    0788966052
# 9998    0327754591
# Length: 412485, dtype: object

# %%
os.chdir('..')
os.chdir('outcome')

# %%
sents.to_excel('sent-phones.xlsx', index=False)

# %%
os.chdir('..')

# %%
os.chdir('sent-phone')
sent2.to_excel('anh-tham-da-gui-5-6-7-8.xlsx', index=False)

# %%
sent1.to_excel('phuoc-da-gui-8.xlsx', index=False)
